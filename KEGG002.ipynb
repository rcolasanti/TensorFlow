# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from pprint import pprint

# %matplotlib inline

# %%
#full_data = pd.read_csv("datasets/wine/wine_train.csv")
full_data = pd.read_csv("datasets/KEGG/kegg_train.csv")
target = full_data[["I_Node"]]
atributes = full_data.drop("I_Node", axis=1) # drop labels for training set
atributes = atributes.drop("Pathway", axis=1) # drop labels for training set
atributes = atributes.drop("Isolated_Nodes", axis=1) # drop labels for training set
full_data.head()
# Out:
#     Pathway  Connected_Components_Integer  Diameter  Radius Centralization  \
# 0  rsh00051                             4         4       1    0.072727273
# 1  det00350                             3         1       1              0
# 2  ecj00626                             4         2       1    0.142857143
# 3  sco00750                             3         2       1    0.107142857
# 4  mtc00642                             2         2       1    0.366666667
#
#    Shortest_Path  Characteristic_Path_Length  Avg.num.Neighbours   Density  \
# 0             30                    1.733333            1.333333  0.121212
# 1              6                    1.000000            1.000000  0.200000
# 2             12                    1.166667            1.111111  0.138889
# 3             18                    1.333333            1.333333  0.166667
# 4             18                    1.444444            1.428571  0.238095
#
#    Heterogeneity  ...  BetweennessCentrality  Radiality  Eccentricity  \
# 0       0.353553  ...               0.222222   0.854167      2.083333
# 1       0.000000  ...               0.000000   1.000000      1.000000
# 2       0.282843  ...               0.111111   0.944444      1.222222
# 3       0.353553  ...               0.333333   0.833333      1.666667
# 4       0.509902  ...               0.285714   0.785714      1.714286
#
#    NumberOfUndirectedEdges  ClosenessCentrality  AverageShortestPathLength  \
# 0                      0.0             0.745238                   1.500000
# 1                      0.0             1.000000                   1.000000
# 2                      0.0             0.925926                   1.111111
# 3                      0.0             0.777778                   1.333333
# 4                      0.0             0.733333                   1.428571
#
#    ClusteringCoefficient  nodeCount  edgeCount  I_Node
# 0                    0.0         12         13       0
# 1                    0.0          6          4       0
# 2                    0.0          9          5       0
# 3                    0.0          9          9       0
# 4                    0.0          7          5       0
#
# [5 rows x 30 columns]

# %%
data_list = [
 'Characteristic_Path_Length',
 'Avg.num.Neighbours',
 'Density',
 'Heterogeneity',
 'Multi-edge_Node_Pair',
 'NeighborhoodConnectivity',
 'NumberOfDirectedEdges_real',
 'Stress',
 'Partner_Of_MultiEdged_NodePairs',
 'TopologicalCoefficient',
 'BetweennessCentrality',
 'Radiality',
 'Eccentricity',
 'ClosenessCentrality',
 'AverageShortestPathLength']

# %%
atributes =  atributes[data_list]

# %%
target.head()
# Out:
#    I_Node
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
atributes.describe()
# Out:
#        Characteristic_Path_Length  Avg.num.Neighbours       Density  \
# count                52443.000000        52443.000000  52443.000000
# mean                     2.093387            1.557023      0.222537
# std                      1.147130            0.444052      0.188811
# min                      1.000000            0.666667      0.008210
# 25%                      1.250000            1.200000      0.100000
# 50%                      1.705882            1.500000      0.153846
# 75%                      2.607143            1.833333      0.300000
# max                     15.972929            3.440000      1.000000
#
#        Heterogeneity  Multi-edge_Node_Pair  NeighborhoodConnectivity  \
# count   52443.000000          52443.000000              52443.000000
# mean        0.375459              4.114963                  1.952080
# std         0.207278              6.441100                  0.776466
# min         0.000000              0.000000                  0.666667
# 25%         0.316228              0.000000                  1.400000
# 50%         0.353553              2.000000                  1.800000
# 75%         0.492548              5.000000                  2.377778
# max         1.796203            220.000000                 15.604820
#
#        NumberOfDirectedEdges_real        Stress  \
# count                52443.000000  52443.000000
# mean                     2.169055     18.212064
# std                      1.025559     43.634432
# min                      0.666667      0.000000
# 25%                      1.400000      0.476190
# 50%                      2.000000      2.428571
# 75%                      2.666667     14.117647
# max                     10.222222   2112.055556
#
#        Partner_Of_MultiEdged_NodePairs  TopologicalCoefficient  \
# count                     52443.000000            52443.000000
# mean                          0.506119                0.169253
# std                           0.533160                0.175700
# min                           0.000000                0.000000
# 25%                           0.000000                0.000000
# 50%                           0.375000                0.150000
# 75%                           0.800000                0.284167
# max                           3.000000                1.000000
#
#        BetweennessCentrality     Radiality  Eccentricity  ClosenessCentrality  \
# count           52443.000000  5.244300e+04  52443.000000         52443.000000
# mean                0.174986  1.079859e+08      2.994240             0.671639
# std                 0.101026  1.027056e+09      2.238039             0.230113
# min                 0.000000  5.437276e-01      0.666667             0.102206
# 25%                 0.114368  7.462121e-01      1.400000             0.492923
# 50%                 0.185185  8.214286e-01      2.235294             0.693939
# 75%                 0.244444  9.000000e-01      3.800000             0.866667
# max                 0.333333  3.074457e+10     25.034091             1.000000
#
#        AverageShortestPathLength
# count               52443.000000
# mean                    1.946092
# std                     1.037721
# min                     0.666667
# 25%                     1.200000
# 50%                     1.590476
# 75%                     2.351648
# max                    12.667032

# %%
list(atributes)
# Out:
# ['Characteristic_Path_Length',
#  'Avg.num.Neighbours',
#  'Density',
#  'Heterogeneity',
#  'Multi-edge_Node_Pair',
#  'NeighborhoodConnectivity',
#  'NumberOfDirectedEdges_real',
#  'Stress',
#  'Partner_Of_MultiEdged_NodePairs',
#  'TopologicalCoefficient',
#  'BetweennessCentrality',
#  'Radiality',
#  'Eccentricity',
#  'ClosenessCentrality',
#  'AverageShortestPathLength']

# %%
from sklearn.preprocessing import OneHotEncoder
cat_encoder = OneHotEncoder(categories='auto')
target_hot = cat_encoder.fit_transform(target).toarray()

# %%
#target = np.array(full_data["Cultivator"].copy(),dtype=int)
target = np.array(target["I_Node"],dtype=int)
pprint(target)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

attribs_labels = list(atributes)
pprint(attribs_labels)

# Replace any missing values with the median value
# Nomalize all the data

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('nomalize', MinMaxScaler()),
    ])


full_pipeline = ColumnTransformer([
        ("num", num_pipeline, attribs_labels),
#        ("cat", OneHotEncoder(), cat_attribs),
    ])
# Out:
# ['Characteristic_Path_Length',
#  'Avg.num.Neighbours',
#  'Density',
#  'Heterogeneity',
#  'Multi-edge_Node_Pair',
#  'NeighborhoodConnectivity',
#  'NumberOfDirectedEdges_real',
#  'Stress',
#  'Partner_Of_MultiEdged_NodePairs',
#  'TopologicalCoefficient',
#  'BetweennessCentrality',
#  'Radiality',
#  'Eccentricity',
#  'ClosenessCentrality',
#  'AverageShortestPathLength']

# %%
attribs = full_pipeline.fit_transform(atributes)

# %%
attribs
# Out:
# array([[0.04897728, 0.24038462, 0.11393739, ..., 0.05813773, 0.7162356 ,
#         0.06944233],
#        [0.        , 0.12019231, 0.19337748, ..., 0.01367947, 1.        ,
#         0.02777693],
#        [0.0111312 , 0.16025641, 0.13176049, ..., 0.02279911, 0.91749322,
#         0.03703591],
#        ...,
#        [0.08517788, 0.43269231, 0.12615894, ..., 0.09849215, 0.45738362,
#         0.12120843],
#        [0.0222624 , 0.48076923, 0.66390728, ..., 0.05471786, 0.7215396 ,
#         0.05555387],
#        [0.03596234, 0.32051282, 0.18777594, ..., 0.05015804, 0.5792154 ,
#         0.05555387]])

# %%
dataset = {"attribs_labels":attribs_labels,"attribs":attribs.tolist(),"target":target.tolist(),"target_hot":target_hot.tolist()}

# %%
#with open("datasets/wine/wine_train.json","w") as jout:
with open("datasets/KEGG/kegg_train.json","w") as jout:
    json.dump(dataset,jout)
